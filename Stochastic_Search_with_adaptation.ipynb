# %%
import numpy as np
from sklearn import svm
from sklearn.linear_model import LinearRegression
import optunity.metrics as metrics
from sklearn.neural_network import MLPRegressor as mlpr
from pylab import rcParams
import pandas as pd
import data_preprocessor
import random
import copy
import matplotlib.pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML
import matplotlib
import matplotlib.animation as animation
import matplotlib.patches as patches
from pylab import rcParams

class Q_Criterion:
    def __init__(self, X_train, y_train, X_test, y_test):
        self.X_train = X_train
        self.y_train = y_train
        
        self.X_test = X_test
        self.y_test = y_test
        
    def get_list_of_indexes_by_bitmask(self, bitmask):
        ls = []
        for i in range(len(bitmask)):
            if bitmask[i] == 1:
                ls.append(i)
                
        return ls 
    
    def calc_Q(self, feature_bitmask):
        list_of_features = self.get_list_of_indexes_by_bitmask(feature_bitmask)
        
        model = LinearRegression()
        model.fit(self.X_train[:, list_of_features], self.y_train)
        
        y_hat = model.predict(self.X_test[:, list_of_features])
        Q = metrics.mse(y_hat, self.y_test)
        return Q
        
        
class Stochastic_Search:
    def __init__(self):
        return
    
    
    
    # -------------------------------------------------------------------------
    def draw(self, mode, data, additional_information = []):    
        output_plot = plt.figure(dpi = 40)
        
        output_subplot = output_plot.add_subplot(111, aspect = 'equal')
        
        area_for_arrows = 0.2
        a = (1.0-area_for_arrows)/len(data[0])
        border_width = a/10
 
        plt.text(0.4, 0.4, mode, size = 50, rotation = -10.0, color = 'white',
                 ha = "center", va = "center",
                 bbox = dict(boxstyle = "round",
                          ec = (0.1, 0.1, 0.1),
                          fc = (0.1, 0.1, 0.1)),
        )
        
        for k in range(len(data)):
            cur_col = 'black'
            if k == 1:
                cur_col = 'blue'
            if k == 2:
                cur_col = 'red'
            
            for i in range(len(data[k])):
                if len(additional_information) > 0:
                    if k == 0:
                        if additional_information[i] == 0:
                            cur_col = 'blue'
                        else:
                            cur_col = 'red'
                    
                
                output_subplot.add_patch(
                        patches.Rectangle(
                            (a*i+border_width, k*a+border_width),   # (x,y)
                            a-2*border_width,          # width
                            a-2*border_width,          # height
                            color = 'black',
                            alpha = data[k][i]
                        )
                    )
                            
                output_subplot.add_patch(
                        patches.Rectangle(
                            (a*i+border_width, k*a+border_width),   # (x,y)
                            a-2*border_width,          # width
                            a-2*border_width,          # height
                            color = cur_col,
                            fill = False,
                            linewidth = 4
                        )
                    )
                        
                if mode == 'Mutation':
                    output_subplot.add_patch(
                        patches.FancyArrowPatch(
                            (0.81, 1.5*a),
                            (0.81, a/2),
                            connectionstyle = 'arc3, rad = -0.7',
                            mutation_scale = 20,
                            color = 'green'
                        )
                    )
                        
                if mode == 'Crossover':
                    output_subplot.add_patch(
                        patches.FancyArrowPatch(
                            (0.81, 2.5*a),
                            (0.85, a/2),
                            connectionstyle = 'arc3, rad = -0.9',
                            mutation_scale = 20,
                            color = 'green'
                        )
                    )
                    
                    output_subplot.add_patch(
                        patches.FancyArrowPatch(
                            (0.81, 1.5*a),
                            (0.81, a/2),
                            connectionstyle = 'arc3, rad = -0.7',
                            mutation_scale = 20,
                            color = 'green'
                        )
                    )
                    
                
        output_plot.set_size_inches(18.5, 10.5, forward=True)
                
        output_plot.canvas.draw()           
        output_plot.show()

        plt.show()
        plt.draw_all()
            
    # -------------------------------------------------------------------------
    
    
    def draw_Q(self, Q):
        plt.plot(Q, 'ro-', color = 'green', label = 'min Q')

        plt.xlabel('Iteration')
        plt.ylabel('Q')
        plt.title('Q best on iteration')   
        
        plt.rcParams["figure.figsize"] = (12, 4)
        
        plt.show()
    
    # ------------------------------------------------------------------------- 
    
    def count_ones_in_bitmask(self, v):
        cnt = 0
        for k in range(len(v)):
            if v[k] == True:
                cnt+=1
        return cnt
    
    def calc_lower_envelope(self, R, Q):
        lower_envelope = [self.INF] * self.n
        
        for i in range(len(R)):
            j = self.count_ones_in_bitmask(R[i])     
            lower_envelope[j] = min(lower_envelope[j], Q[i])
            
        return lower_envelope
        
    def draw_lower_envelope(self, lower_envelope, index, right_bound):
        index += 1
        right_bound += 1
        
        x = []
        y = []
        
        for j in range(len(lower_envelope)):
            if lower_envelope[j] < self.INF:
                x.append(j)
                y.append(lower_envelope[j])
                
                
        marker = 'ro'
        if index == right_bound:
            marker = 'ro-'
                
        plt.plot(x, y, marker, 
                 color = ((right_bound-index)/right_bound, 
                          (right_bound-index)/right_bound, 
                          (right_bound-index)/right_bound
                         )
                )
                
        return
    
    def draw_p_difference(self, prev_p, p):
        ind = np.arange(len(p))    # the x locations for the groups
        width = 0.35 
        
        diff = np.array(p)-np.array(prev_p)
        diff *= -1
        
        diff1 = []
        diff2 = []
        
        for k in range(len(p)):
            diff1.append(max(diff[k], 0.0))
            diff2.append(min(diff[k], 0.0))
        
        p1 = plt.bar(ind, p, width)
        p2 = plt.bar(ind, diff1, width, bottom = p, color = 'red')
        p3 = plt.bar(ind, diff2, width, bottom = p, color = 'green')
        
        plt.ylabel('p')
        plt.xlabel('Feature')
        plt.title('Probability')
        
        plt.show()
        
    
    def fit(self, X_train, y_train, q_criterion, d, T, r, h, visualization):
        self.X_train = X_train
        self.y_train = y_train
        self.d = d
        self.T = T
        self.r = r
        self.h = h
        
        self.INF = 1E9
        
        rand_gen = random.Random()
        
        # n - number of features
        self.n = len(X_train[0])
        
        # init feature probabilities
        p = [1.0/self.n] * self.n
        prev_p = copy.deepcopy(p)
        
        Q_best_history = []
        
        lower_envelope_history = []
        
        # ---------------------------------------------------------------------
            
        best_F = []
        Q_best  = self.INF
     
        for t in range(T):
            if visualization == True:
                self.draw_p_difference(prev_p, p)
            
            R = []
            while (len(R) < r):
                obj = []
                for k in range(self.n):
                    flag = rand_gen.choices([True, False], weights = [p[k], 1-p[k]], k = 1)[0]
                    obj.append(flag)
                    
                if self.count_ones_in_bitmask(obj) > 0:
                    R.append(obj)
                        
            
            Q = []
            for i in range(len(R)):
                Q.append(q_criterion.calc_Q(R[i]))
                
            R = [x for _,x in sorted(zip(Q, R))]
            
            Q = []
            for i in range(len(R)):
                Q.append(q_criterion.calc_Q(R[i]))
                
            print('Best Q on iteration: ', Q[0])
            print('Best Q:', Q_best)
            
            if visualization == True:
                lower_envelope = self.calc_lower_envelope(R, Q)
                
                lower_envelope_history.append(lower_envelope)
                
                for k in range(len(lower_envelope_history)):
                    self.draw_lower_envelope(lower_envelope_history[k], index = k, 
                                             right_bound = t)
            
            
            plt.show()
        
            F_min = R[0]
            F_max = R[len(R)-1]
            
            H = 0.0
            
            prev_p = copy.deepcopy(p)
            
            for k in range(len(F_max)):
                if F_max[k] == True:
                    delta_p_k = min(p[k], h)
                    p[k] -= delta_p_k
                    H += delta_p_k
                    
            cnt_ones_in_F_min = self.count_ones_in_bitmask(F_min)
                    
            for k in range(len(F_min)):
                if F_min[k] == True:
                    p[k] += H/cnt_ones_in_F_min
            
            
            if Q[0] < Q_best:
                Q_best = copy.deepcopy(Q[0])
                best_F = R[0]
            
            Q_best_history.append(Q[0])
        
            print('Iteration:', t)
    
    
        print('Best Q:', q_criterion.calc_Q(best_F))
        if visualization == True:
            self.draw_Q(Q_best_history)
        return best_F
           
            
    # -------------------------------------------------------------------------
            
def print_feature_names(F, names_of_features):
    for i in range(len(F)):
        if F[i] == 1:
            print(names_of_features[i], end = ' ')
    print()
    
        
def main():
    dp = data_preprocessor.Data_Preprocessor()
    X_train, y_train, X_test, y_test, names_of_features = dp.Prepare_data('diabetes')
    
    q_criterion = Q_Criterion(X_train, y_train, X_test, y_test)
    
    ss = Stochastic_Search()
    
    n = len(X_train[0])
    r = 500
    
    F = ss.fit(X_train, y_train, q_criterion, d = 1, T = 300, r = r, h = 1.0/(r * n), visualization = False)    
    
    print_feature_names(F, names_of_features)
    
    
main()
# Out:
# Best Q on iteration:  3302.572149932065
# Best Q: 1000000000.0
# Iteration: 0
# Best Q on iteration:  3067.1077629354622
# Best Q: 3302.572149932065
# Iteration: 1
# Best Q on iteration:  3287.3262060002544
# Best Q: 3067.1077629354622
# Iteration: 2
# Best Q on iteration:  3062.0681787697804
# Best Q: 3067.1077629354622
# Iteration: 3
# Best Q on iteration:  3191.3196725972916
# Best Q: 3062.0681787697804
# Iteration: 4
# Best Q on iteration:  3292.080215233633
# Best Q: 3062.0681787697804
# Iteration: 5
# Best Q on iteration:  3122.5466749880725
# Best Q: 3062.0681787697804
# Iteration: 6
# Best Q on iteration:  3269.9702105375577
# Best Q: 3062.0681787697804
# Iteration: 7
# Best Q on iteration:  3307.8450317057905
# Best Q: 3062.0681787697804
# Iteration: 8
# Best Q on iteration:  3302.572149932065
# Best Q: 3062.0681787697804
# Iteration: 9
# Best Q on iteration:  3302.572149932065
# Best Q: 3062.0681787697804
# Iteration: 10
# Best Q on iteration:  3150.400545556058
# Best Q: 3062.0681787697804
# Iteration: 11
# Best Q on iteration:  3015.0009754829
# Best Q: 3062.0681787697804
# Iteration: 12
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 13
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 14
# Best Q on iteration:  3331.931577320835
# Best Q: 3015.0009754829
# Iteration: 15
# Best Q on iteration:  3246.923899023127
# Best Q: 3015.0009754829
# Iteration: 16
# Best Q on iteration:  3079.3414198481505
# Best Q: 3015.0009754829
# Iteration: 17
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 18
# Best Q on iteration:  3101.3680238573374
# Best Q: 3015.0009754829
# Iteration: 19
# Best Q on iteration:  3364.8881514208038
# Best Q: 3015.0009754829
# Iteration: 20
# Best Q on iteration:  3112.328124068183
# Best Q: 3015.0009754829
# Iteration: 21
# Best Q on iteration:  3079.3414198481505
# Best Q: 3015.0009754829
# Iteration: 22
# Best Q on iteration:  3316.8807715942626
# Best Q: 3015.0009754829
# Iteration: 23
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 24
# Best Q on iteration:  3118.6397705979
# Best Q: 3015.0009754829
# Iteration: 25
# Best Q on iteration:  3079.3414198481505
# Best Q: 3015.0009754829
# Iteration: 26
# Best Q on iteration:  3316.8807715942626
# Best Q: 3015.0009754829
# Iteration: 27
# Best Q on iteration:  3164.6141459179153
# Best Q: 3015.0009754829
# Iteration: 28
# Best Q on iteration:  3067.1077629354622
# Best Q: 3015.0009754829
# Iteration: 29
# Best Q on iteration:  3067.1077629354622
# Best Q: 3015.0009754829
# Iteration: 30
# Best Q on iteration:  3067.1077629354622
# Best Q: 3015.0009754829
# Iteration: 31
# Best Q on iteration:  3268.3933801596327
# Best Q: 3015.0009754829
# Iteration: 32
# Best Q on iteration:  3240.3556487184037
# Best Q: 3015.0009754829
# Iteration: 33
# Best Q on iteration:  3331.931577320835
# Best Q: 3015.0009754829
# Iteration: 34
# Best Q on iteration:  3079.3414198481505
# Best Q: 3015.0009754829
# Iteration: 35
# Best Q on iteration:  3058.2865954165736
# Best Q: 3015.0009754829
# Iteration: 36
# Best Q on iteration:  3079.3414198481505
# Best Q: 3015.0009754829
# Iteration: 37
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 38
# Best Q on iteration:  3316.8807715942626
# Best Q: 3015.0009754829
# Iteration: 39
# Best Q on iteration:  3269.9702105375577
# Best Q: 3015.0009754829
# Iteration: 40
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 41
# Best Q on iteration:  3331.931577320835
# Best Q: 3015.0009754829
# Iteration: 42
# Best Q on iteration:  3057.5775975941115
# Best Q: 3015.0009754829
# Iteration: 43
# Best Q on iteration:  3316.8807715942626
# Best Q: 3015.0009754829
# Iteration: 44
# Best Q on iteration:  3147.524492649263
# Best Q: 3015.0009754829
# Iteration: 45
# Best Q on iteration:  3079.3414198481505
# Best Q: 3015.0009754829
# Iteration: 46
# Best Q on iteration:  3147.524492649263
# Best Q: 3015.0009754829
# Iteration: 47
# Best Q on iteration:  3364.195173063599
# Best Q: 3015.0009754829
# Iteration: 48
# Best Q on iteration:  3062.897249170468
# Best Q: 3015.0009754829
# Iteration: 49
# Best Q on iteration:  3062.0681787697804
# Best Q: 3015.0009754829
# Iteration: 50
# Best Q on iteration:  3302.572149932065
# Best Q: 3015.0009754829
# Iteration: 51
# Best Q on iteration:  3149.1153074679796
# Best Q: 3015.0009754829
# Iteration: 52
# Best Q on iteration:  3164.6141459179153
# Best Q: 3015.0009754829
# Iteration: 53
# Best Q on iteration:  3112.328124068183
# Best Q: 3015.0009754829
# Iteration: 54
# Best Q on iteration:  3302.572149932065
# Best Q: 3015.0009754829
# Iteration: 55
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 56
# Best Q on iteration:  3294.239858555057
# Best Q: 3015.0009754829
# Iteration: 57
# Best Q on iteration:  3269.9702105375577
# Best Q: 3015.0009754829
# Iteration: 58
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 59
# Best Q on iteration:  3302.572149932065
# Best Q: 3015.0009754829
# Iteration: 60
# Best Q on iteration:  3228.6811751819755
# Best Q: 3015.0009754829
# Iteration: 61
# Best Q on iteration:  3271.258633266258
# Best Q: 3015.0009754829
# Iteration: 62
# Best Q on iteration:  3127.9709285701165
# Best Q: 3015.0009754829
# Iteration: 63
# Best Q on iteration:  3286.1606759285787
# Best Q: 3015.0009754829
# Iteration: 64
# Best Q on iteration:  3127.9709285701165
# Best Q: 3015.0009754829
# Iteration: 65
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 66
# Best Q on iteration:  3268.7677654132503
# Best Q: 3015.0009754829
# Iteration: 67
# Best Q on iteration:  3149.1153074679796
# Best Q: 3015.0009754829
# Iteration: 68
# Best Q on iteration:  3079.3414198481505
# Best Q: 3015.0009754829
# Iteration: 69
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 70
# Best Q on iteration:  3258.8333689964834
# Best Q: 3015.0009754829
# Iteration: 71
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 72
# Best Q on iteration:  3260.8550292348
# Best Q: 3015.0009754829
# Iteration: 73
# Best Q on iteration:  3316.8807715942626
# Best Q: 3015.0009754829
# Iteration: 74
# Best Q on iteration:  3147.524492649263
# Best Q: 3015.0009754829
# Iteration: 75
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 76
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 77
# Best Q on iteration:  3316.8807715942626
# Best Q: 3015.0009754829
# Iteration: 78
# Best Q on iteration:  3164.6141459179153
# Best Q: 3015.0009754829
# Iteration: 79
# Best Q on iteration:  3112.328124068183
# Best Q: 3015.0009754829
# Iteration: 80
# Best Q on iteration:  3062.0681787697804
# Best Q: 3015.0009754829
# Iteration: 81
# Best Q on iteration:  3294.239858555057
# Best Q: 3015.0009754829
# Iteration: 82
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 83
# Best Q on iteration:  3364.195173063599
# Best Q: 3015.0009754829
# Iteration: 84
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 85
# Best Q on iteration:  3331.931577320835
# Best Q: 3015.0009754829
# Iteration: 86
# Best Q on iteration:  3127.9709285701165
# Best Q: 3015.0009754829
# Iteration: 87
# Best Q on iteration:  3331.931577320835
# Best Q: 3015.0009754829
# Iteration: 88
# Best Q on iteration:  3295.836675231169
# Best Q: 3015.0009754829
# Iteration: 89
# Best Q on iteration:  3125.018292521464
# Best Q: 3015.0009754829
# Iteration: 90
# Best Q on iteration:  3268.3933801596327
# Best Q: 3015.0009754829
# Iteration: 91
# Best Q on iteration:  3067.1077629354622
# Best Q: 3015.0009754829
# Iteration: 92
# Best Q on iteration:  3307.8450317057905
# Best Q: 3015.0009754829
# Iteration: 93
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 94
# Best Q on iteration:  3164.6141459179153
# Best Q: 3015.0009754829
# Iteration: 95
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 96
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 97
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 98
# Best Q on iteration:  3302.572149932065
# Best Q: 3015.0009754829
# Iteration: 99
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 100
# Best Q on iteration:  3147.524492649263
# Best Q: 3015.0009754829
# Iteration: 101
# Best Q on iteration:  3127.9709285701165
# Best Q: 3015.0009754829
# Iteration: 102
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 103
# Best Q on iteration:  3067.1077629354622
# Best Q: 3015.0009754829
# Iteration: 104
# Best Q on iteration:  3086.082768850167
# Best Q: 3015.0009754829
# Iteration: 105
# Best Q on iteration:  3304.8112430770943
# Best Q: 3015.0009754829
# Iteration: 106
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 107
# Best Q on iteration:  3302.572149932065
# Best Q: 3015.0009754829
# Iteration: 108
# Best Q on iteration:  3248.065317194957
# Best Q: 3015.0009754829
# Iteration: 109
# Best Q on iteration:  3258.8333689964834
# Best Q: 3015.0009754829
# Iteration: 110
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 111
# Best Q on iteration:  3335.941115936342
# Best Q: 3015.0009754829
# Iteration: 112
# Best Q on iteration:  3127.9709285701165
# Best Q: 3015.0009754829
# Iteration: 113
# Best Q on iteration:  3147.524492649263
# Best Q: 3015.0009754829
# Iteration: 114
# Best Q on iteration:  3079.3414198481505
# Best Q: 3015.0009754829
# Iteration: 115
# Best Q on iteration:  3147.524492649263
# Best Q: 3015.0009754829
# Iteration: 116
# Best Q on iteration:  3271.258633266258
# Best Q: 3015.0009754829
# Iteration: 117
# Best Q on iteration:  3164.6141459179153
# Best Q: 3015.0009754829
# Iteration: 118
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 119
# Best Q on iteration:  3127.9709285701165
# Best Q: 3015.0009754829
# Iteration: 120
# Best Q on iteration:  3067.1077629354622
# Best Q: 3015.0009754829
# Iteration: 121
# Best Q on iteration:  3364.8881514208038
# Best Q: 3015.0009754829
# Iteration: 122
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 123
# Best Q on iteration:  3147.524492649263
# Best Q: 3015.0009754829
# Iteration: 124
# Best Q on iteration:  3302.572149932065
# Best Q: 3015.0009754829
# Iteration: 125
# Best Q on iteration:  3269.9702105375577
# Best Q: 3015.0009754829
# Iteration: 126
# Best Q on iteration:  3164.6141459179153
# Best Q: 3015.0009754829
# Iteration: 127
# Best Q on iteration:  3127.9709285701165
# Best Q: 3015.0009754829
# Iteration: 128
# Best Q on iteration:  3227.6437393087704
# Best Q: 3015.0009754829
# Iteration: 129
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 130
# Best Q on iteration:  3147.524492649263
# Best Q: 3015.0009754829
# Iteration: 131
# Best Q on iteration:  3067.1077629354622
# Best Q: 3015.0009754829
# Iteration: 132
# Best Q on iteration:  3269.9702105375577
# Best Q: 3015.0009754829
# Iteration: 133
# Best Q on iteration:  3086.0301733411643
# Best Q: 3015.0009754829
# Iteration: 134
# Best Q on iteration:  3240.3556487184037
# Best Q: 3015.0009754829
# Iteration: 135
# Best Q on iteration:  3026.8348446401938
# Best Q: 3015.0009754829
# Iteration: 136
# Best Q on iteration:  3203.7846557935472
# Best Q: 3015.0009754829
# Iteration: 137
# Best Q on iteration:  3269.9702105375577
# Best Q: 3015.0009754829
# Iteration: 138
# Best Q on iteration:  3149.1153074679796
# Best Q: 3015.0009754829
# Iteration: 139
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 140
# Best Q on iteration:  3149.1153074679796
# Best Q: 3015.0009754829
# Iteration: 141
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 142
# Best Q on iteration:  3149.1153074679796
# Best Q: 3015.0009754829
# Iteration: 143
# Best Q on iteration:  3227.6437393087704
# Best Q: 3015.0009754829
# Iteration: 144
# Best Q on iteration:  3294.239858555057
# Best Q: 3015.0009754829
# Iteration: 145
# Best Q on iteration:  3246.923899023127
# Best Q: 3015.0009754829
# Iteration: 146
# Best Q on iteration:  3026.8348446401938
# Best Q: 3015.0009754829
# Iteration: 147
# Best Q on iteration:  3127.9709285701165
# Best Q: 3015.0009754829
# Iteration: 148
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 149
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 150
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 151
# Best Q on iteration:  3302.572149932065
# Best Q: 3015.0009754829
# Iteration: 152
# Best Q on iteration:  3258.8333689964834
# Best Q: 3015.0009754829
# Iteration: 153
# Best Q on iteration:  3067.1077629354622
# Best Q: 3015.0009754829
# Iteration: 154
# Best Q on iteration:  3283.122285850579
# Best Q: 3015.0009754829
# Iteration: 155
# Best Q on iteration:  3086.0301733411643
# Best Q: 3015.0009754829
# Iteration: 156
# Best Q on iteration:  3028.4679972620197
# Best Q: 3015.0009754829
# Iteration: 157
# Best Q on iteration:  3150.400545556058
# Best Q: 3015.0009754829
# Iteration: 158
# Best Q on iteration:  3112.328124068183
# Best Q: 3015.0009754829
# Iteration: 159
# Best Q on iteration:  3302.572149932065
# Best Q: 3015.0009754829
# Iteration: 160
# Best Q on iteration:  3302.572149932065
# Best Q: 3015.0009754829
# Iteration: 161
# Best Q on iteration:  3164.6141459179153
# Best Q: 3015.0009754829
# Iteration: 162
# Best Q on iteration:  3227.6437393087704
# Best Q: 3015.0009754829
# Iteration: 163
# Best Q on iteration:  3269.9702105375577
# Best Q: 3015.0009754829
# Iteration: 164
# Best Q on iteration:  3112.328124068183
# Best Q: 3015.0009754829
# Iteration: 165
# Best Q on iteration:  3062.897249170468
# Best Q: 3015.0009754829
# Iteration: 166
# Best Q on iteration:  2990.647916074318
# Best Q: 3015.0009754829
# Iteration: 167
# Best Q on iteration:  3268.3933801596327
# Best Q: 2990.647916074318
# Iteration: 168
# Best Q on iteration:  3164.6141459179153
# Best Q: 2990.647916074318
# Iteration: 169
# Best Q on iteration:  3296.3269096528397
# Best Q: 2990.647916074318
# Iteration: 170
# Best Q on iteration:  3067.1077629354622
# Best Q: 2990.647916074318
# Iteration: 171
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 172
# Best Q on iteration:  3302.572149932065
# Best Q: 2990.647916074318
# Iteration: 173
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 174
# Best Q on iteration:  3296.3269096528397
# Best Q: 2990.647916074318
# Iteration: 175
# Best Q on iteration:  3302.572149932065
# Best Q: 2990.647916074318
# Iteration: 176
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 177
# Best Q on iteration:  3268.3933801596327
# Best Q: 2990.647916074318
# Iteration: 178
# Best Q on iteration:  3271.258633266258
# Best Q: 2990.647916074318
# Iteration: 179
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 180
# Best Q on iteration:  3191.3196725972916
# Best Q: 2990.647916074318
# Iteration: 181
# Best Q on iteration:  3030.548164930872
# Best Q: 2990.647916074318
# Iteration: 182
# Best Q on iteration:  3074.9085833099657
# Best Q: 2990.647916074318
# Iteration: 183
# Best Q on iteration:  3067.1077629354622
# Best Q: 2990.647916074318
# Iteration: 184
# Best Q on iteration:  3083.918701888946
# Best Q: 2990.647916074318
# Iteration: 185
# Best Q on iteration:  3127.9709285701165
# Best Q: 2990.647916074318
# Iteration: 186
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 187
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 188
# Best Q on iteration:  3149.1153074679796
# Best Q: 2990.647916074318
# Iteration: 189
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 190
# Best Q on iteration:  3067.1077629354622
# Best Q: 2990.647916074318
# Iteration: 191
# Best Q on iteration:  3147.524492649263
# Best Q: 2990.647916074318
# Iteration: 192
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 193
# Best Q on iteration:  3149.1153074679796
# Best Q: 2990.647916074318
# Iteration: 194
# Best Q on iteration:  3026.8348446401938
# Best Q: 2990.647916074318
# Iteration: 195
# Best Q on iteration:  3147.524492649263
# Best Q: 2990.647916074318
# Iteration: 196
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 197
# Best Q on iteration:  3062.0681787697804
# Best Q: 2990.647916074318
# Iteration: 198
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 199
# Best Q on iteration:  3149.1153074679796
# Best Q: 2990.647916074318
# Iteration: 200
# Best Q on iteration:  3385.5143066333244
# Best Q: 2990.647916074318
# Iteration: 201
# Best Q on iteration:  3077.692898424406
# Best Q: 2990.647916074318
# Iteration: 202
# Best Q on iteration:  3077.692898424406
# Best Q: 2990.647916074318
# Iteration: 203
# Best Q on iteration:  3149.1153074679796
# Best Q: 2990.647916074318
# Iteration: 204
# Best Q on iteration:  3227.6437393087704
# Best Q: 2990.647916074318
# Iteration: 205
# Best Q on iteration:  3268.3933801596327
# Best Q: 2990.647916074318
# Iteration: 206
# Best Q on iteration:  3331.931577320835
# Best Q: 2990.647916074318
# Iteration: 207
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 208
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 209
# Best Q on iteration:  3302.572149932065
# Best Q: 2990.647916074318
# Iteration: 210
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 211
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 212
# Best Q on iteration:  3034.9587391075493
# Best Q: 2990.647916074318
# Iteration: 213
# Best Q on iteration:  3146.1124430869513
# Best Q: 2990.647916074318
# Iteration: 214
# Best Q on iteration:  3316.8807715942626
# Best Q: 2990.647916074318
# Iteration: 215
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 216
# Best Q on iteration:  3112.328124068183
# Best Q: 2990.647916074318
# Iteration: 217
# Best Q on iteration:  3028.4679972620197
# Best Q: 2990.647916074318
# Iteration: 218
# Best Q on iteration:  3062.0681787697804
# Best Q: 2990.647916074318
# Iteration: 219
# Best Q on iteration:  3269.9702105375577
# Best Q: 2990.647916074318
# Iteration: 220
# Best Q on iteration:  3302.572149932065
# Best Q: 2990.647916074318
# Iteration: 221
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 222
# Best Q on iteration:  3316.8807715942626
# Best Q: 2990.647916074318
# Iteration: 223
# Best Q on iteration:  3112.328124068183
# Best Q: 2990.647916074318
# Iteration: 224
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 225
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 226
# Best Q on iteration:  3067.1077629354622
# Best Q: 2990.647916074318
# Iteration: 227
# Best Q on iteration:  3127.9709285701165
# Best Q: 2990.647916074318
# Iteration: 228
# Best Q on iteration:  3067.1077629354622
# Best Q: 2990.647916074318
# Iteration: 229
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 230
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 231
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 232
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 233
# Best Q on iteration:  3297.8062260410384
# Best Q: 2990.647916074318
# Iteration: 234
# Best Q on iteration:  3225.9340396931784
# Best Q: 2990.647916074318
# Iteration: 235
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 236
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 237
# Best Q on iteration:  3118.6397705979
# Best Q: 2990.647916074318
# Iteration: 238
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 239
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 240
# Best Q on iteration:  3067.1077629354622
# Best Q: 2990.647916074318
# Iteration: 241
# Best Q on iteration:  3112.328124068183
# Best Q: 2990.647916074318
# Iteration: 242
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 243
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 244
# Best Q on iteration:  3147.524492649263
# Best Q: 2990.647916074318
# Iteration: 245
# Best Q on iteration:  3079.6785602896502
# Best Q: 2990.647916074318
# Iteration: 246
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 247
# Best Q on iteration:  3302.572149932065
# Best Q: 2990.647916074318
# Iteration: 248
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 249
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 250
# Best Q on iteration:  3062.897249170468
# Best Q: 2990.647916074318
# Iteration: 251
# Best Q on iteration:  3295.591554695754
# Best Q: 2990.647916074318
# Iteration: 252
# Best Q on iteration:  3030.548164930872
# Best Q: 2990.647916074318
# Iteration: 253
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 254
# Best Q on iteration:  3112.328124068183
# Best Q: 2990.647916074318
# Iteration: 255
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 256
# Best Q on iteration:  3067.1077629354622
# Best Q: 2990.647916074318
# Iteration: 257
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 258
# Best Q on iteration:  3147.524492649263
# Best Q: 2990.647916074318
# Iteration: 259
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 260
# Best Q on iteration:  3031.943109597784
# Best Q: 2990.647916074318
# Iteration: 261
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 262
# Best Q on iteration:  3127.9709285701165
# Best Q: 2990.647916074318
# Iteration: 263
# Best Q on iteration:  3077.692898424406
# Best Q: 2990.647916074318
# Iteration: 264
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 265
# Best Q on iteration:  3067.1077629354622
# Best Q: 2990.647916074318
# Iteration: 266
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 267
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 268
# Best Q on iteration:  3147.524492649263
# Best Q: 2990.647916074318
# Iteration: 269
# Best Q on iteration:  3086.0301733411643
# Best Q: 2990.647916074318
# Iteration: 270
# Best Q on iteration:  3164.6141459179153
# Best Q: 2990.647916074318
# Iteration: 271
# Best Q on iteration:  3112.328124068183
# Best Q: 2990.647916074318
# Iteration: 272
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 273
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 274
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 275
# Best Q on iteration:  3112.328124068183
# Best Q: 2990.647916074318
# Iteration: 276
# Best Q on iteration:  3227.6437393087704
# Best Q: 2990.647916074318
# Iteration: 277
# Best Q on iteration:  3062.0681787697804
# Best Q: 2990.647916074318
# Iteration: 278
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 279
# Best Q on iteration:  3308.0519551123766
# Best Q: 2990.647916074318
# Iteration: 280
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 281
# Best Q on iteration:  3127.9709285701165
# Best Q: 2990.647916074318
# Iteration: 282
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 283
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 284
# Best Q on iteration:  3112.328124068183
# Best Q: 2990.647916074318
# Iteration: 285
# Best Q on iteration:  3026.8348446401938
# Best Q: 2990.647916074318
# Iteration: 286
# Best Q on iteration:  3164.6141459179153
# Best Q: 2990.647916074318
# Iteration: 287
# Best Q on iteration:  3112.328124068183
# Best Q: 2990.647916074318
# Iteration: 288
# Best Q on iteration:  3269.4947935146047
# Best Q: 2990.647916074318
# Iteration: 289
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 290
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 291
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 292
# Best Q on iteration:  3127.9709285701165
# Best Q: 2990.647916074318
# Iteration: 293
# Best Q on iteration:  3067.1077629354622
# Best Q: 2990.647916074318
# Iteration: 294
# Best Q on iteration:  3147.524492649263
# Best Q: 2990.647916074318
# Iteration: 295
# Best Q on iteration:  3150.400545556058
# Best Q: 2990.647916074318
# Iteration: 296
# Best Q on iteration:  3079.3414198481505
# Best Q: 2990.647916074318
# Iteration: 297
# Best Q on iteration:  3302.801970853378
# Best Q: 2990.647916074318
# Iteration: 298
# Best Q on iteration:  3149.1153074679796
# Best Q: 2990.647916074318
# Iteration: 299
# Best Q: 2990.647916074318
# SEX BMI BP S2 S3 S5
